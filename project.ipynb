# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6, 5))
sns.heatmap(np.loadtxt("output/initial_collapsed_matrix.txt"), cmap="viridis", annot=True)
plt.title("Heatmap of Collapsed Matrix")
plt.show()
plt.figure(figsize=(6, 5))
sns.heatmap(np.loadtxt("output/initial_raw_collapsed_matrix.txt"), cmap="viridis", annot=True)
plt.title("Heatmap of RAW Collapsed Matrix")
plt.show()

# %%
plt.figure(figsize=(6, 5))
sns.heatmap(np.loadtxt("output/initial_HSR_collapsed_matrix.txt"), cmap="viridis", annot=True)
plt.title("Heatmap of HSR Collapsed Matrix")
plt.show()
plt.figure(figsize=(6, 5))
sns.heatmap(np.loadtxt("output/initial_HSR_raw_collapsed_matrix.txt"), cmap="viridis", annot=True)
plt.title("Heatmap of HSR RAW Collapsed Matrix")
plt.show()
